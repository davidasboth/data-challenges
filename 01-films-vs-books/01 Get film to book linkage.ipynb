# %% [markdown]
# # Scrape Wikipedia tables of films based on books
#
# Parent page: https://en.wikipedia.org/wiki/Lists_of_works_of_fiction_made_into_feature_films

# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO

# %% [markdown]
# Get main page HTML

# %%
main_page_wiki = wikipedia.page("Lists of works of fiction made into feature films")
main_page_soup = BeautifulSoup(main_page_wiki.html())

# %% [markdown]
# Get relevant \<a\> tags

# %%
sub_page_tags = [
    tag for tag in main_page_soup.select("a") if tag.text.startswith("List of")
]

# print for sanity
for title in [tag.text for tag in sub_page_tags]:
    print(title)
# Out:
# List of fiction works made into feature films (0–9, A–C)
# List of fiction works made into feature films (D–J)
# List of fiction works made into feature films (K–R)
# List of fiction works made into feature films (S–Z)
# List of short fiction made into feature films
# List of children's books made into feature films
# List of films based on comics
# List of comics and comic strips made into feature films
# List of plays adapted into feature films
# List of non-fiction works made into feature films

# %% [markdown]
# Function to extract all DataFrames from a single subpage (which contains multiple tables, one per starting letter)

# %%
def collect_tables(subpage_title):
    subpage_frames = []
    subpage_title = "List of fiction works made into feature films (0–9, A–C)"
    subpage = wikipedia.page(subpage_title)
    subpage_soup = BeautifulSoup(subpage.html())
    wikitables = subpage_soup.select("table.wikitable")
    for table in wikitables:
        # convert soup object to str to represent HTML
        # pass that to pandas to extract DataFrame
        table_df = pd.read_html(StringIO(str(table)))[0]
        subpage_frames.append(table_df)

    return subpage_frames

# %% [markdown]
# For each page, collect tables

# %%
all_frames = []

for sub_page_tag in sub_page_tags:
    subpage_tables = collect_tables(sub_page_tag.text)
    all_frames.extend(subpage_tables)

len(all_frames)
# Out:
# 40

# %%
films_to_books = pd.concat(all_frames, axis=0, ignore_index=True)
print(films_to_books.shape)
films_to_books.head()
# Out:
# (7320, 2)
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)
# 0                                   25th Hour (2002)
# 1                                 Grasshopper (2015)
# 2                            Murder, She Said (1961)
# 3  Crime Is Our Business (French: Le Crime est no...
# 4                                  Die Hard 2 (1990)

# %% [markdown]
# Let's make some simplifying assumptions:
#
# - author is always at the end of the "fiction work" after the last comma
# - if we find 4 numbers + any other character (we have things like "1996-present" for book series) in brackets in either the fiction work or the film, it's the publication date
# - the book/film title is everything up to the first `(` (this may not end well, who knows?)

# %%
# author
# note: in book ratings data, multiple authors are comma separated
films_to_books["author"] = (
    films_to_books["Fiction work(s)"]
    .str.split(",")
    .str[-1]
    .str.replace(" and ", ", ")
    .str.strip()
    .str.upper()
)

# publication dates
films_to_books["book_published_date"] = films_to_books["Fiction work(s)"].str.extract(
    r"\((\d{4}.*?)\)"
)
films_to_books["film_published_date"] = films_to_books[
    "Film adaptation(s)"
].str.extract(r"\((\d{4}.*?)\)")


# titles
def get_clean_title(title):
    if "(" in title:
        return title[: title.index("(")].upper().strip()
    return title.upper().strip()


films_to_books["book_title"] = films_to_books["Fiction work(s)"].apply(get_clean_title)
films_to_books["film_title"] = films_to_books["Film adaptation(s)"].apply(
    get_clean_title
)

films_to_books.sample(20, random_state=42)
# Out:
#                                         Fiction work(s)  \
# 2574              Billy Bathgate (1989), E. L. Doctorow
# 1562         The Age of Innocence (1921), Edith Wharton
# 4477    The Adventures of Tom Sawyer (1876), Mark Twain
# 2826                       Cimarron (1929), Edna Ferber
# 3720  The Adventures of Pinocchio (Italian: Le avven...
# 2415  The Apprenticeship of Duddy Kravitz (1959), Mo...
# 3463               The Caine Mutiny (1952), Herman Wouk
# 1512  The Adventures of Pinocchio (Italian: Le avven...
# 1891  Blood and Sand (Spanish: Sangre y arena) (1908...
# 4336  A Connecticut Yankee in King Arthur's Court (1...
# 6046  Anna Karenina (serialised 1873–1887, published...
# 3405  Bourne (1980–2012) (series)[N 11], Robert Ludl...
# 4601               Anthony Adverse (1933), Hervey Allen
# 3544     Christmas at Twenty-Nine (2002), Kamato Toshio
# 1498  Adventures of Huckleberry Finn (1884), Mark Twain
# 6658    The Adventures of Tom Sawyer (1876), Mark Twain
# 1740               Baise-moi (1993), Virginie Despentes
# 2208                  Across 110th (1970), Wally Ferris
# 6080  Around the World in Eighty Days (French: Le to...
# 132              Altered States (1978), Paddy Chayefsky
#
#                                      Film adaptation(s)  \
# 2574                              Billy Bathgate (1991)
# 1562                        The Age of Innocence (1928)
# 4477  The Animated Adventures of Tom Sawyer (1998)[N 1]
# 2826                                    Cimarron (1960)
# 3720                                   Pinocchio (2019)
# 2415         The Apprenticeship of Duddy Kravitz (1974)
# 3463         The Caine Mutiny Court-Martial (1955)[N 1]
# 1512      Pinocchio and the Emperor of the Night (1987)
# 1891                              Blood and Sand (1916)
# 4336                        A Connecticut Yankee (1931)
# 6046                               Anna Karenina (1974)
# 3405                                Jason Bourne (2016)
# 4601                             Anthony Adverse (1936)
# 3544                                     Singles (2003)
# 1498                 The Adventures of Huck Finn (1993)
# 6658                                  Tom Sawyer (1917)
# 1740                                   Baise-moi (2000)
# 2208                         Across 110th Street (1972)
# 6080                 Around the World in 80 Days (1956)
# 132                               Altered States (1980)
#
#                                  author book_published_date  \
# 2574                     E. L. DOCTOROW                1989
# 1562                      EDITH WHARTON                1921
# 4477                         MARK TWAIN                1876
# 2826                        EDNA FERBER                1929
# 3720                      CARLO COLLODI                1883
# 2415                   MORDECAI RICHLER                1959
# 3463                        HERMAN WOUK                1952
# 1512                      CARLO COLLODI                1883
# 1891              VICENTE BLASCO IBÁÑEZ                1908
# 4336                         MARK TWAIN                1889
# 6046                        LEO TOLSTOY                 NaN
# 3405  ROBERT LUDLUM, ERIC VAN LUSTBADER           1980–2012
# 4601                       HERVEY ALLEN                1933
# 3544                      KAMATO TOSHIO                2002
# 1498                         MARK TWAIN                1884
# 6658                         MARK TWAIN                1876
# 1740                 VIRGINIE DESPENTES                1993
# 2208                       WALLY FERRIS                1970
# 6080                        JULES VERNE                1873
# 132                     PADDY CHAYEFSKY                1978
#
#      film_published_date                                   book_title  \
# 2574                1991                               BILLY BATHGATE
# 1562                1928                         THE AGE OF INNOCENCE
# 4477                1998                 THE ADVENTURES OF TOM SAWYER
# 2826                1960                                     CIMARRON
# 3720                2019                  THE ADVENTURES OF PINOCCHIO
# 2415                1974          THE APPRENTICESHIP OF DUDDY KRAVITZ
# 3463                1955                             THE CAINE MUTINY
# 1512                1987                  THE ADVENTURES OF PINOCCHIO
# 1891                1916                               BLOOD AND SAND
# 4336                1931  A CONNECTICUT YANKEE IN KING ARTHUR'S COURT
# 6046                1974                                ANNA KARENINA
# 3405                2016                                       BOURNE
# 4601                1936                              ANTHONY ADVERSE
# 3544                2003                     CHRISTMAS AT TWENTY-NINE
# 1498                1993               ADVENTURES OF HUCKLEBERRY FINN
# 6658                1917                 THE ADVENTURES OF TOM SAWYER
# 1740                2000                                    BAISE-MOI
# 2208                1972                                 ACROSS 110TH
# 6080                1956              AROUND THE WORLD IN EIGHTY DAYS
# 132                 1980                               ALTERED STATES
#
#                                   film_title
# 2574                          BILLY BATHGATE
# 1562                    THE AGE OF INNOCENCE
# 4477   THE ANIMATED ADVENTURES OF TOM SAWYER
# 2826                                CIMARRON
# 3720                               PINOCCHIO
# 2415     THE APPRENTICESHIP OF DUDDY KRAVITZ
# 3463          THE CAINE MUTINY COURT-MARTIAL
# 1512  PINOCCHIO AND THE EMPEROR OF THE NIGHT
# 1891                          BLOOD AND SAND
# 4336                    A CONNECTICUT YANKEE
# 6046                           ANNA KARENINA
# 3405                            JASON BOURNE
# 4601                         ANTHONY ADVERSE
# 3544                                 SINGLES
# 1498             THE ADVENTURES OF HUCK FINN
# 6658                              TOM SAWYER
# 1740                               BAISE-MOI
# 2208                     ACROSS 110TH STREET
# 6080             AROUND THE WORLD IN 80 DAYS
# 132                           ALTERED STATES

# %%
films_to_books.to_parquet("./data/films_to_books.parquet", index=False)
