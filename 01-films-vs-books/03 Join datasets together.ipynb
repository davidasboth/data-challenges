# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Base data (film to book linkage)

# %%
films_to_books = pd.read_parquet("./data/films_to_books.parquet")
films_to_books.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)           author  \
# 0                                   25th Hour (2002)    DAVID BENIOFF
# 1                                 Grasshopper (2015)     KŌTARŌ ISAKA
# 2                            Murder, She Said (1961)  AGATHA CHRISTIE
# 3  Crime Is Our Business (French: Le Crime est no...  AGATHA CHRISTIE
# 4                                  Die Hard 2 (1990)     WALTER WAGER
#
#   book_published_date film_published_date            book_title  \
# 0                2001                2002         THE 25TH HOUR
# 1                2004                2015           3 ASSASSINS
# 2                1957                1961  4.50 FROM PADDINGTON
# 3                1957                2008  4.50 FROM PADDINGTON
# 4                1987                1990            58 MINUTES
#
#               film_title
# 0              25TH HOUR
# 1            GRASSHOPPER
# 2       MURDER, SHE SAID
# 3  CRIME IS OUR BUSINESS
# 4             DIE HARD 2

# %% [markdown]
# Film published date is a bit messy, take the first 4 characters as the year (some are things like "1972; Australian") and convert to float

# %%
films_to_books["film_published_date"] = (
    films_to_books["film_published_date"].str[:4].astype(float)
)
films_to_books.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)           author  \
# 0                                   25th Hour (2002)    DAVID BENIOFF
# 1                                 Grasshopper (2015)     KŌTARŌ ISAKA
# 2                            Murder, She Said (1961)  AGATHA CHRISTIE
# 3  Crime Is Our Business (French: Le Crime est no...  AGATHA CHRISTIE
# 4                                  Die Hard 2 (1990)     WALTER WAGER
#
#   book_published_date  film_published_date            book_title  \
# 0                2001               2002.0         THE 25TH HOUR
# 1                2004               2015.0           3 ASSASSINS
# 2                1957               1961.0  4.50 FROM PADDINGTON
# 3                1957               2008.0  4.50 FROM PADDINGTON
# 4                1987               1990.0            58 MINUTES
#
#               film_title
# 0              25TH HOUR
# 1            GRASSHOPPER
# 2       MURDER, SHE SAID
# 3  CRIME IS OUR BUSINESS
# 4             DIE HARD 2

# %%
films_to_books["book_published_date"].unique()
# Out:
# array(['2001', '2004', '1957', '1987', '1936', '1998', '1996', '1985',
#        '1970', '1969', '2000', '1971', '1999', '1816', '1911', '1966',
#        '1996–present', '1866', '1824', '1884', '1883', None, '1876',
#        '1959', '1923', '1935', '2017', '1955', '1979', '1953', '1921',
#        '1961', '1968', '1887', '1960', '1946', '1919', '1929', '1992',
#        '2009', '1895', '1976', '1993', '1978', '1948', '1990', '1965',
#        '1995', '1991', '1976–2008', '1925', '1927', '1943', '1977',
#        '2005', '1958', '1942', '1939', '1957–2012', '1956', '2014',
#        '1944', '1909', '1908', '1937', '1933', '1938', '1951', '1873',
#        '1949', '1963', '1983', '1982', '1877', '1854', '1912', '1975',
#        '1914', '1997', '1981', '1989', '1931', '1928', '1954', '1972',
#        '1900', '1947', '1890', '2003', '1907', '1924', '1926', '1945',
#        '1930', '1932', '1885', '1880', '1941', '1952', '1932–1968',
#        '1888', '1941–1989', '1984', '1964', '1973', '1916', '1934',
#        '1906', '1980–2012', '2006', '1986', '1988', '1974', '1940',
#        '1996–2016', '2007', '1903', '1922', '1962', '1902', '1994',
#        '1999–2006', '2002', '1950–1956', '1964—1968', '1980', '1905',
#        '1889', '1844–1846', '1875'], dtype=object)

# %% [markdown]
# Delete any publication date that isn't a number

# %%
films_to_books.loc[
    films_to_books["book_published_date"].str.isnumeric() == False,
    "book_published_date",
] = np.nan

films_to_books["book_published_date"] = films_to_books["book_published_date"].astype(
    float
)

# %% [markdown]
# ## Join book ratings data

# %%
book_ratings = pd.read_parquet("./data/book_ratings.parquet")
print(book_ratings.shape)
book_ratings.head()
# Out:
# (10000, 8)
#    goodreads_book_id                      authors  original_publication_year  \
# 0            2767052              SUZANNE COLLINS                     2008.0
# 1                  3  J.K. ROWLING, MARY GRANDPRÉ                     1997.0
# 2              41865              STEPHENIE MEYER                     2005.0
# 3               2657                   HARPER LEE                     1960.0
# 4               4671          F. SCOTT FITZGERALD                     1925.0
#
#                              original_title  \
# 0                          THE HUNGER GAMES
# 1  HARRY POTTER AND THE PHILOSOPHER'S STONE
# 2                                  TWILIGHT
# 3                     TO KILL A MOCKINGBIRD
# 4                          THE GREAT GATSBY
#
#                                                title  average_rating  \
# 0            THE HUNGER GAMES (THE HUNGER GAMES, #1)            4.34
# 1  HARRY POTTER AND THE SORCERER'S STONE (HARRY P...            4.44
# 2                            TWILIGHT (TWILIGHT, #1)            3.57
# 3                              TO KILL A MOCKINGBIRD            4.25
# 4                                   THE GREAT GATSBY            3.89
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#    average_rating_normalised
# 0                       86.8
# 1                       88.8
# 2                       71.4
# 3                       85.0
# 4                       77.8

# %% [markdown]
# Based on previous exploration, join only on title

# %%
print(len(films_to_books))

merged_book_ratings = films_to_books.merge(
    book_ratings, left_on="book_title", right_on="original_title", how="inner"
)

print(
    f"{len(merged_book_ratings)} books merged on title alone ({100 * (len(merged_book_ratings) / len(films_to_books)):.1f}%)"
)

merged_book_ratings.head()
# Out:
# 7320
# 2270 books merged on title alone (31.0%)
#                                 Fiction work(s)  \
# 0  4.50 from Paddington (1957), Agatha Christie
# 1  4.50 from Paddington (1957), Agatha Christie
# 2               About a Boy (1998), Nick Hornby
# 3         Absolute Power (1996), David Baldacci
# 4     The Accidental Tourist (1985), Anne Tyler
#
#                                   Film adaptation(s)           author  \
# 0                            Murder, She Said (1961)  AGATHA CHRISTIE
# 1  Crime Is Our Business (French: Le Crime est no...  AGATHA CHRISTIE
# 2                                 About a Boy (2002)      NICK HORNBY
# 3                              Absolute Power (1997)   DAVID BALDACCI
# 4                      The Accidental Tourist (1988)       ANNE TYLER
#
#    book_published_date  film_published_date              book_title  \
# 0               1957.0               1961.0    4.50 FROM PADDINGTON
# 1               1957.0               2008.0    4.50 FROM PADDINGTON
# 2               1998.0               2002.0             ABOUT A BOY
# 3               1996.0               1997.0          ABSOLUTE POWER
# 4               1985.0               1988.0  THE ACCIDENTAL TOURIST
#
#                film_title  goodreads_book_id                       authors  \
# 0        MURDER, SHE SAID             140278               AGATHA CHRISTIE
# 1   CRIME IS OUR BUSINESS             140278               AGATHA CHRISTIE
# 2             ABOUT A BOY               4271                   NICK HORNBY
# 3          ABSOLUTE POWER              15159                DAVID BALDACCI
# 4  THE ACCIDENTAL TOURIST              60792  ANNE TYLER, JENNIFER BASSETT
#
#    original_publication_year          original_title  \
# 0                     1957.0    4.50 FROM PADDINGTON
# 1                     1957.0    4.50 FROM PADDINGTON
# 2                     1998.0             ABOUT A BOY
# 3                     1995.0          ABSOLUTE POWER
# 4                     1985.0  THE ACCIDENTAL TOURIST
#
#                                     title  average_rating  \
# 0  4:50 FROM PADDINGTON (MISS MARPLE, #8)            3.92
# 1  4:50 FROM PADDINGTON (MISS MARPLE, #8)            3.92
# 2                             ABOUT A BOY            3.79
# 3                          ABSOLUTE POWER            4.15
# 4                  THE ACCIDENTAL TOURIST            3.90
#
#                                      small_image_url  \
# 0  https://s.gr-assets.com/assets/nophoto/book/50...
# 1  https://s.gr-assets.com/assets/nophoto/book/50...
# 2  https://images.gr-assets.com/books/1382004144s...
# 3  https://images.gr-assets.com/books/1328399707s...
# 4  https://images.gr-assets.com/books/1502220282s...
#
#    average_rating_normalised
# 0                       78.4
# 1                       78.4
# 2                       75.8
# 3                       83.0
# 4                       78.0

# %% [markdown]
# # Films
#
# Let's try joining on:
#
# - title ONLY
# - title AND release date

# %%
film_ratings = pd.read_parquet("./data/film_metacritic_ratings.parquet")
print(film_ratings.shape)
film_ratings.head()
# Out:
# (12846, 12)
#    Unnamed: 0                     Title  Release Date  \
# 0           0            Dekalog (1988)  Mar 22, 1996
# 1           1         Three Colors: Red  Nov 23, 1994
# 2           2            The Conformist  Oct 22, 1970
# 3           3               Tokyo Story  Mar 13, 1972
# 4           4  The Leopard (re-release)  Aug 13, 2004
#
#                                          Description  Rating  \
# 0  This masterwork by Krzysztof Kieślowski is one...    74.0
# 1  Krzysztof Kieslowski closes his Three Colors t...    83.0
# 2  Set in Rome in the 1930s, this re-release of B...    73.0
# 3  Yasujiro Ozu’s Tokyo Story follows an aging co...    81.0
# 4  Set in Sicily in 1860, Luchino Visconti's spec...    78.0
#
#   No of Persons Voted           Directed by  \
# 0                 118  Krzysztof Kieslowski
# 1                 241  Krzysztof Kieslowski
# 2                 106   Bernardo Bertolucci
# 3                 147          Yasujirô Ozu
# 4                  85      Luchino Visconti
#
#                                           Written by  Duration  \
# 0         Krzysztof Kieslowski, Krzysztof Piesiewicz  9 h 32 m
# 1  Krzysztof Kieslowski, Krzysztof Piesiewicz, Ag...  1 h 39 m
# 2               Alberto Moravia, Bernardo Bertolucci  1 h 47 m
# 3                            Kôgo Noda, Yasujirô Ozu  2 h 16 m
# 4  Giuseppe Tomasi di Lampedusa, Suso Cecchi D'Am...   3 h 7 m
#
#                   Genres         film_title  film_published_date
# 0                  Drama     DEKALOG (1988)                 1996
# 1  Drama,Mystery,Romance  THREE COLORS: RED                 1994
# 2                  Drama     THE CONFORMIST                 1970
# 3                  Drama        TOKYO STORY                 1972
# 4          Drama,History        THE LEOPARD                 2004

# %%
print(len(films_to_books))

merged_film_ratings = films_to_books.merge(film_ratings, on="film_title", how="inner")

print(
    f"{len(merged_film_ratings)} films merged on title alone ({100 * (len(merged_film_ratings) / len(films_to_books)):.1f}%)"
)
# Out:
# 7320
# 3650 films merged on title alone (49.9%)

# %% [markdown]
# What about adding date to disambiguate between films with the same title?

# %%
print(len(films_to_books))

merged_film_ratings_2 = films_to_books.merge(
    film_ratings, on=["film_title", "film_published_date"], how="inner"
)

print(
    f"{len(merged_film_ratings_2)} films merged on title AND date ({100 * (len(merged_film_ratings_2) / len(films_to_books)):.1f}%)"
)
# Out:
# 7320
# 1480 films merged on title AND date (20.2%)

# %% [markdown]
# Let's join Metacritic ratings only on title

# %%
print(len(merged_book_ratings))

merged_film_ratings = merged_book_ratings.merge(
    film_ratings, on="film_title", how="inner"
)

print(merged_film_ratings.shape)

merged_film_ratings.head()
# Out:
# 2270
# (1570, 26)
#                                      Fiction work(s)  \
# 0                    About a Boy (1998), Nick Hornby
# 1              Absolute Power (1996), David Baldacci
# 2          The Accidental Tourist (1985), Anne Tyler
# 3  The Adventures of Sherlock Holmes (serialised ...
# 4  The Adventures of Sherlock Holmes (serialised ...
#
#               Film adaptation(s)              author  book_published_date  \
# 0             About a Boy (2002)         NICK HORNBY               1998.0
# 1          Absolute Power (1997)      DAVID BALDACCI               1996.0
# 2  The Accidental Tourist (1988)          ANNE TYLER               1985.0
# 3         Sherlock Holmes (1916)  ARTHUR CONAN DOYLE                  NaN
# 4         Sherlock Holmes (1922)  ARTHUR CONAN DOYLE                  NaN
#
#    film_published_date_x                         book_title  \
# 0                 2002.0                        ABOUT A BOY
# 1                 1997.0                     ABSOLUTE POWER
# 2                 1988.0             THE ACCIDENTAL TOURIST
# 3                 1916.0  THE ADVENTURES OF SHERLOCK HOLMES
# 4                 1922.0  THE ADVENTURES OF SHERLOCK HOLMES
#
#                film_title  goodreads_book_id                       authors  \
# 0             ABOUT A BOY               4271                   NICK HORNBY
# 1          ABSOLUTE POWER              15159                DAVID BALDACCI
# 2  THE ACCIDENTAL TOURIST              60792  ANNE TYLER, JENNIFER BASSETT
# 3         SHERLOCK HOLMES               3590            ARTHUR CONAN DOYLE
# 4         SHERLOCK HOLMES               3590            ARTHUR CONAN DOYLE
#
#    original_publication_year  ...                   Title  Release Date  \
# 0                     1998.0  ...             About a Boy  May 17, 2002
# 1                     1995.0  ...          Absolute Power  Feb 14, 1997
# 2                     1985.0  ...  The Accidental Tourist  Dec 23, 1988
# 3                     1892.0  ...         Sherlock Holmes  Dec 25, 2009
# 4                     1892.0  ...         Sherlock Holmes  Dec 25, 2009
#
#                                          Description Rating  \
# 0  About a Boy is about a man (Grant) -- a handso...   74.0
# 1  He was where he shouldn't have been, saw what ...   65.0
# 2  An author of travel books (Hurt) sees his worl...   66.0
# 3  Sherlock Holmes has made his reputation findin...   77.0
# 4  Sherlock Holmes has made his reputation findin...   77.0
#
#    No of Persons Voted                            Directed by  \
# 0                   99  Chris Weitz, \n    \n      Paul Weitz
# 1                   42                         Clint Eastwood
# 2                   13                        Lawrence Kasdan
# 3                  558                            Guy Ritchie
# 4                  558                            Guy Ritchie
#
#                                           Written by  Duration  \
# 0  Nick Hornby, Peter Hedges, Chris Weitz, Paul W...  1 h 41 m
# 1                    David Baldacci, William Goldman   2 h 1 m
# 2          Anne Tyler, Frank Galati, Lawrence Kasdan   2 h 1 m
# 3  Michael Robert Johnson, Anthony Peckham, Simon...   2 h 8 m
# 4  Michael Robert Johnson, Anthony Peckham, Simon...   2 h 8 m
#
#                         Genres  film_published_date_y
# 0         Comedy,Drama,Romance                   2002
# 1  Action,Crime,Drama,Thriller                   1997
# 2         Comedy,Drama,Romance                   1988
# 3     Action,Adventure,Mystery                   2009
# 4     Action,Adventure,Mystery                   2009
#
# [5 rows x 26 columns]

# %%
final_data = (
    merged_film_ratings[
        [
            "book_title",
            "author",
            "book_published_date",
            "average_rating_normalised",
            "film_title",
            "film_published_date_y",
            "Rating",
        ]
    ]
    .drop_duplicates()
    .rename(
        columns={
            "average_rating_normalised": "avg_book_rating",
            "Rating": "avg_film_rating",
            "film_published_date_y": "film_published_date",
        }
    )
)

print(final_data.shape)
final_data.sort_values("book_title")
# Out:
# (87, 7)
#                                       book_title           author  \
# 134                           A CLOCKWORK ORANGE  ANTHONY BURGESS
# 145  A CONNECTICUT YANKEE IN KING ARTHUR'S COURT       MARK TWAIN
# 0                                    ABOUT A BOY      NICK HORNBY
# 1                                 ABSOLUTE POWER   DAVID BALDACCI
# 6                                          AFTER        ANNA TODD
# ..                                           ...              ...
# 131                            THE CITY OF EMBER    JEANNE DUPRAU
# 133                                   THE CLIENT     JOHN GRISHAM
# 136                             THE COLOR PURPLE     ALICE WALKER
# 138                             THE COLOR PURPLE     ALICE WALKER
# 146                        THE CONSTANT GARDENER    JOHN LE CARRÉ
#
#      book_published_date  avg_book_rating             film_title  \
# 134               1962.0             79.6     A CLOCKWORK ORANGE
# 145               1889.0             75.2           BLACK KNIGHT
# 0                 1998.0             75.8            ABOUT A BOY
# 1                 1996.0             83.0         ABSOLUTE POWER
# 6                 2017.0             74.8                  AFTER
# ..                   ...              ...                    ...
# 131               2003.0             77.0          CITY OF EMBER
# 133               1993.0             79.4             THE CLIENT
# 136               1982.0             83.4       THE COLOR PURPLE
# 138               1982.0             83.4       THE COLOR PURPLE
# 146               2001.0             75.6  THE CONSTANT GARDENER
#
#      film_published_date  avg_film_rating
# 134                 1971             73.0
# 145                 2001             93.0
# 0                   2002             74.0
# 1                   1997             65.0
# 6                   2019             99.0
# ..                   ...              ...
# 131                 2008             64.0
# 133                 1994             71.0
# 136                 1985             82.0
# 138                 2023             82.0
# 146                 2005             72.0
#
# [87 rows x 7 columns]

# %% [markdown]
# Quick check - any films better?

# %%
final_data[final_data["avg_film_rating"] > final_data["avg_book_rating"]]
# Out:
#                                       book_title               author  \
# 6                                          AFTER            ANNA TODD
# 8                                          AFTER            ANNA TODD
# 10                                         AFTER            ANNA TODD
# 12                                         AFTER            ANNA TODD
# 21                               AMERICAN PSYCHO    BRET EASTON ELLIS
# 22                         THE AMITYVILLE HORROR            JAY ANSON
# 24                         THE AMITYVILLE HORROR            JAY ANSON
# 30                          THE ANDROMEDA STRAIN     MICHAEL CRICHTON
# 35                                  ASK THE DUST           JOHN FANTE
# 36                                     ATONEMENT           IAN MCEWAN
# 38                                     THE BEACH         ALEX GARLAND
# 41                                       BEL-AMI    GUY DE MAUPASSANT
# 55       BIG FISH: A NOVEL OF MYTHIC PROPORTIONS       DANIEL WALLACE
# 56                                   BIG TROUBLE           DAVE BARRY
# 58                                   BIG TROUBLE           DAVE BARRY
# 85                 THE BRIDGES OF MADISON COUNTY  ROBERT JAMES WALLER
# 109                                CASINO ROYALE          IAN FLEMING
# 118                          THE CHILDREN OF MEN          P. D. JAMES
# 130                        THE CIDER HOUSE RULES          JOHN IRVING
# 144                                        CONGO     MICHAEL CRICHTON
# 145  A CONNECTICUT YANKEE IN KING ARTHUR'S COURT           MARK TWAIN
# 148                                        CRASH        J. G. BALLARD
# 150                                        CRASH        J. G. BALLARD
# 152                                        CRASH        J. G. BALLARD
# 154                                        CRASH        J. G. BALLARD
#
#      book_published_date  avg_book_rating                     film_title  \
# 6                 2017.0             74.8                          AFTER
# 8                 2017.0             74.8                          AFTER
# 10                2017.0             74.6                          AFTER
# 12                2017.0             74.6                          AFTER
# 21                1991.0             76.2                AMERICAN PSYCHO
# 22                1977.0             76.4          THE AMITYVILLE HORROR
# 24                1977.0             76.4          THE AMITYVILLE HORROR
# 30                1969.0             77.4           THE ANDROMEDA STRAIN
# 35                1939.0             82.8                   ASK THE DUST
# 36                2001.0             77.6                      ATONEMENT
# 38                1996.0             78.2                      THE BEACH
# 41                1885.0             76.2                        BEL AMI
# 55                1998.0             72.8                       BIG FISH
# 56                1999.0             76.2                    BIG TROUBLE
# 58                1999.0             76.2                    BIG TROUBLE
# 85                1992.0             70.2  THE BRIDGES OF MADISON COUNTY
# 109               1953.0             74.6                  CASINO ROYALE
# 118               1992.0             73.8                CHILDREN OF MEN
# 130               1985.0             82.0          THE CIDER HOUSE RULES
# 144               1980.0             71.0                          CONGO
# 145               1889.0             75.2                   BLACK KNIGHT
# 148               1973.0             80.4                          CRASH
# 150               1973.0             80.4                          CRASH
# 152               1973.0             71.6                          CRASH
# 154               1973.0             71.6                          CRASH
#
#      film_published_date  avg_film_rating
# 6                   2019             99.0
# 8                   2014             99.0
# 10                  2019             99.0
# 12                  2014             99.0
# 21                  2000             85.0
# 22                  2005             79.0
# 24                  1979             79.0
# 30                  1971             80.0
# 35                  2006             85.0
# 36                  2007             81.0
# 38                  2000             80.0
# 41                  2012             77.0
# 55                  2003             84.0
# 56                  1986             85.0
# 58                  2002             85.0
# 85                  1995             85.0
# 109                 2006             88.0
# 118                 2006             89.0
# 130                 1999             87.0
# 144                 1995             81.0
# 145                 2001             93.0
# 148                 2005             86.0
# 150                 1997             86.0
# 152                 2005             86.0
# 154                 1997             86.0

# %%
film_ratings[film_ratings["film_title"] == "CRASH"]
# Out:
#       Unnamed: 0  Title  Release Date  \
# 5174        6563  Crash   May 6, 2005
# 5175        6564  Crash   May 6, 2005
# 5176        6565  Crash  Mar 21, 1997
# 5177        6566  Crash  Mar 21, 1997
#
#                                             Description  Rating  \
# 5174  A provocative, unflinching look at the complex...    86.0
# 5175  A provocative, unflinching look at the complex...    86.0
# 5176  The immediate subject matter of Crash is the s...    86.0
# 5177  The immediate subject matter of Crash is the s...    86.0
#
#      No of Persons Voted  Directed by                  Written by  Duration  \
# 5174                 564  Paul Haggis  Paul Haggis, Bobby Moresco  1 h 52 m
# 5175                 564  Paul Haggis  Paul Haggis, Bobby Moresco  1 h 52 m
# 5176                 564  Paul Haggis  Paul Haggis, Bobby Moresco  1 h 52 m
# 5177                 564  Paul Haggis  Paul Haggis, Bobby Moresco  1 h 52 m
#
#                     Genres film_title  film_published_date
# 5174  Crime,Drama,Thriller      CRASH                 2005
# 5175  Crime,Drama,Thriller      CRASH                 2005
# 5176  Crime,Drama,Thriller      CRASH                 1997
# 5177  Crime,Drama,Thriller      CRASH                 1997
