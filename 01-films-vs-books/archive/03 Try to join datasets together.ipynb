# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Base data (film to book linkage)

# %%
films_to_books = pd.read_parquet("./data/films_to_books.parquet")
films_to_books.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)           author  \
# 0                                   25th Hour (2002)    DAVID BENIOFF
# 1                                 Grasshopper (2015)     KŌTARŌ ISAKA
# 2                            Murder, She Said (1961)  AGATHA CHRISTIE
# 3  Crime Is Our Business (French: Le Crime est no...  AGATHA CHRISTIE
# 4                                  Die Hard 2 (1990)     WALTER WAGER
#
#   book_published_date film_published_date            book_title  \
# 0                2001                2002         THE 25TH HOUR
# 1                2004                2015           3 ASSASSINS
# 2                1957                1961  4.50 FROM PADDINGTON
# 3                1957                2008  4.50 FROM PADDINGTON
# 4                1987                1990            58 MINUTES
#
#               film_title
# 0              25TH HOUR
# 1            GRASSHOPPER
# 2       MURDER, SHE SAID
# 3  CRIME IS OUR BUSINESS
# 4             DIE HARD 2

# %%
films_to_books["book_published_date"].unique()
# Out:
# array(['2001', '2004', '1957', '1987', '1936', '1998', '1996', '1985',
#        '1970', '1969', '2000', '1971', '1999', '1816', '1911', '1966',
#        '1996–present', '1866', '1824', '1884', '1883', None, '1876',
#        '1959', '1923', '1935', '2017', '1955', '1979', '1953', '1921',
#        '1961', '1968', '1887', '1960', '1946', '1919', '1929', '1992',
#        '2009', '1895', '1976', '1993', '1978', '1948', '1990', '1965',
#        '1995', '1991', '1976–2008', '1925', '1927', '1943', '1977',
#        '2005', '1958', '1942', '1939', '1957–2012', '1956', '2014',
#        '1944', '1909', '1908', '1937', '1933', '1938', '1951', '1873',
#        '1949', '1963', '1983', '1982', '1877', '1854', '1912', '1975',
#        '1914', '1997', '1981', '1989', '1931', '1928', '1954', '1972',
#        '1900', '1947', '1890', '2003', '1907', '1924', '1926', '1945',
#        '1930', '1932', '1885', '1880', '1941', '1952', '1932–1968',
#        '1888', '1941–1989', '1984', '1964', '1973', '1916', '1934',
#        '1906', '1980–2012', '2006', '1986', '1988', '1974', '1940',
#        '1996–2016', '2007', '1903', '1922', '1962', '1902', '1994',
#        '1999–2006', '2002', '1950–1956', '1964—1968', '1980', '1905',
#        '1889', '1844–1846', '1875'], dtype=object)

# %% [markdown]
# Delete any publication date that isn't a number

# %%
films_to_books.loc[
    films_to_books["book_published_date"].str.isnumeric() == False,
    "book_published_date",
] = np.nan

films_to_books["book_published_date"] = films_to_books["book_published_date"].astype(
    float
)

# %% [markdown]
# ## Join book ratings data

# %%
book_ratings = pd.read_parquet("./data/book_ratings.parquet")
print(book_ratings.shape)
book_ratings.head()
# Out:
# (10000, 8)
#    goodreads_book_id                      authors  original_publication_year  \
# 0            2767052              SUZANNE COLLINS                     2008.0
# 1                  3  J.K. ROWLING, MARY GRANDPRÉ                     1997.0
# 2              41865              STEPHENIE MEYER                     2005.0
# 3               2657                   HARPER LEE                     1960.0
# 4               4671          F. SCOTT FITZGERALD                     1925.0
#
#                              original_title  \
# 0                          THE HUNGER GAMES
# 1  HARRY POTTER AND THE PHILOSOPHER'S STONE
# 2                                  TWILIGHT
# 3                     TO KILL A MOCKINGBIRD
# 4                          THE GREAT GATSBY
#
#                                                title  average_rating  \
# 0            THE HUNGER GAMES (THE HUNGER GAMES, #1)            4.34
# 1  HARRY POTTER AND THE SORCERER'S STONE (HARRY P...            4.44
# 2                            TWILIGHT (TWILIGHT, #1)            3.57
# 3                              TO KILL A MOCKINGBIRD            4.25
# 4                                   THE GREAT GATSBY            3.89
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#    average_rating_normalised
# 0                       86.8
# 1                       88.8
# 2                       71.4
# 3                       85.0
# 4                       77.8

# %% [markdown]
# Let's try joining:
#
# - only on title
# - title AND publication date
# - title AND author (and date?)
# - title (fuzzy match)

# %%
print(len(films_to_books))

merged_book_ratings = films_to_books.merge(
    book_ratings, left_on="book_title", right_on="original_title", how="inner"
)

print(
    f"{len(merged_book_ratings)} books merged on title alone ({100 * (len(merged_book_ratings) / len(films_to_books)):.1f}%)"
)
# Out:
# 7320
# 2270 books merged on title alone (31.0%)

# %% [markdown]
# Title AND date

# %%
print(len(films_to_books))

merged_book_ratings_2 = films_to_books.merge(
    book_ratings,
    left_on=["book_title", "book_published_date"],
    right_on=["original_title", "original_publication_year"],
    how="inner",
)

print(
    f"{len(merged_book_ratings_2)} books merged on title and date ({100 * (len(merged_book_ratings_2) / len(films_to_books)):.1f}%)"
)
# Out:
# 7320
# 1880 books merged on title and date (25.7%)

# %% [markdown]
# Title and author (not date)

# %%
print(len(films_to_books))

merged_book_ratings_3 = films_to_books.merge(
    book_ratings,
    left_on=["book_title", "author"],
    right_on=["original_title", "authors"],
    how="inner",
)

print(
    f"{len(merged_book_ratings_3)} books merged on title and author ({100 * (len(merged_book_ratings_3) / len(films_to_books)):.1f}%)"
)
# Out:
# 7320
# 1420 books merged on title and author (19.4%)

# %% [markdown]
# ### Fuzzy string matching
#
# - for each book in the film-to-book link data, find the closest title in the book ratings data by string similarity (Levenshtein distance)
#     - include a minimum similarity threshold!
# - join the book ratings on this closest match

# %%
from Levenshtein import distance

# %% [markdown]
# Define a function to get similarity

# %%
def most_similar_title(title, all_titles, max_distance=5):
    distances = [
        (s, distance(title, s))
        for s in all_titles
        if distance(title, s) <= max_distance
    ]

    if len(distances) == 0:
        return np.nan

    closest_match = min(distances, key=lambda x: x[1])[0]

    return closest_match


all_book_titles = book_ratings["original_title"].dropna().tolist()

most_similar_title("afughwerydfghdsggd", all_book_titles)
# Out:
# nan

# %% [markdown]
# Call this function on all book titles in book-to-film mapping and see results

# %%
all_book_titles = book_ratings["original_title"].dropna().tolist()

films_to_books["closest_book_match"] = films_to_books["book_title"].apply(
    lambda x: most_similar_title(x, all_book_titles, max_distance=3)
)

films_to_books.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)           author  \
# 0                                   25th Hour (2002)    DAVID BENIOFF
# 1                                 Grasshopper (2015)     KŌTARŌ ISAKA
# 2                            Murder, She Said (1961)  AGATHA CHRISTIE
# 3  Crime Is Our Business (French: Le Crime est no...  AGATHA CHRISTIE
# 4                                  Die Hard 2 (1990)     WALTER WAGER
#
#    book_published_date film_published_date            book_title  \
# 0               2001.0                2002         THE 25TH HOUR
# 1               2004.0                2015           3 ASSASSINS
# 2               1957.0                1961  4.50 FROM PADDINGTON
# 3               1957.0                2008  4.50 FROM PADDINGTON
# 4               1987.0                1990            58 MINUTES
#
#               film_title    closest_book_match
# 0              25TH HOUR                   NaN
# 1            GRASSHOPPER                   NaN
# 2       MURDER, SHE SAID  4.50 FROM PADDINGTON
# 3  CRIME IS OUR BUSINESS  4.50 FROM PADDINGTON
# 4             DIE HARD 2                   NaN

# %%
films_to_books[
    (films_to_books["book_title"] != films_to_books["closest_book_match"])
    & (films_to_books["closest_book_match"].notna())
]
# Out:
#                                         Fiction work(s)  \
# 5     69 (シクスティナイン, Shikusutinain) (1987), Ryu Murakami
# 6            The A.B.C. Murders (1936), Agatha Christie
# 91    Aelita (1923) (a. k. a. Aelita or, The Decline...
# 95                     After Hours (1979), Edwin Torres
# 117       All the King's Men (1946), Robert Penn Warren
# ...                                                 ...
# 7239                    Cocoon (1985), David Saperstein
# 7260                     Conagher (1968), Louis L'Amour
# 7308                       Creator (1980), Jeremy Leven
# 7317                       Cyborg (1972), Martin Caidin
# 7319  The Cypher (a. k. a. The Cipher) (1961), Gordo...
#
#                           Film adaptation(s)              author  \
# 5                                  69 (2004)        RYU MURAKAMI
# 6                The Alphabet Murders (1966)     AGATHA CHRISTIE
# 91                             Aelita (1924)      ALEXEI TOLSTOY
# 95                      Carlito's Way (1993)        EDWIN TORRES
# 117                All the King's Men (1949)  ROBERT PENN WARREN
# ...                                      ...                 ...
# 7239               Cocoon: The Return (1988)    DAVID SAPERSTEIN
# 7260                    Conagher (1991)[N 1]       LOUIS L'AMOUR
# 7308                          Creator (1985)        JEREMY LEVEN
# 7317  The Six Million Dollar Man (1973)[N 1]       MARTIN CAIDIN
# 7319                        Arabesque (1966)       GORDON COTLER
#
#       book_published_date film_published_date          book_title  \
# 5                  1987.0                2004                  69
# 6                  1936.0                1966  THE A.B.C. MURDERS
# 91                 1923.0                1924              AELITA
# 95                 1979.0                1993         AFTER HOURS
# 117                1946.0                1949  ALL THE KING'S MEN
# ...                   ...                 ...                 ...
# 7239               1985.0                1988              COCOON
# 7260               1968.0                1991            CONAGHER
# 7308               1980.0                1985             CREATOR
# 7317               1972.0                1973              CYBORG
# 7319               1961.0                1966          THE CYPHER
#
#                       film_title  closest_book_match
# 5                             69                  IT
# 6           THE ALPHABET MURDERS     THE ABC MURDERS
# 91                        AELITA              LOLITA
# 95                 CARLITO'S WAY           AFTER YOU
# 117           ALL THE KING'S MEN  ALL THE KING’S MEN
# ...                          ...                 ...
# 7239          COCOON: THE RETURN               CONGO
# 7260                    CONAGHER             VOYAGER
# 7308                     CREATOR            PREDATOR
# 7317  THE SIX MILLION DOLLAR MAN             ICEBERG
# 7319                   ARABESQUE          THE RIPPER
#
# [630 rows x 8 columns]

# %% [markdown]
# This is terrible - too many false positive even with an allowable string distance of 3 or fewer characters...
#
# ### Conclusion
#
# Join books on exact title only

# %%
merged_book_ratings = films_to_books.merge(
    book_ratings, left_on="book_title", right_on="original_title", how="inner"
)

merged_book_ratings.head()
# Out:
#                                 Fiction work(s)  \
# 0  4.50 from Paddington (1957), Agatha Christie
# 1  4.50 from Paddington (1957), Agatha Christie
# 2               About a Boy (1998), Nick Hornby
# 3         Absolute Power (1996), David Baldacci
# 4     The Accidental Tourist (1985), Anne Tyler
#
#                                   Film adaptation(s)           author  \
# 0                            Murder, She Said (1961)  AGATHA CHRISTIE
# 1  Crime Is Our Business (French: Le Crime est no...  AGATHA CHRISTIE
# 2                                 About a Boy (2002)      NICK HORNBY
# 3                              Absolute Power (1997)   DAVID BALDACCI
# 4                      The Accidental Tourist (1988)       ANNE TYLER
#
#    book_published_date film_published_date              book_title  \
# 0               1957.0                1961    4.50 FROM PADDINGTON
# 1               1957.0                2008    4.50 FROM PADDINGTON
# 2               1998.0                2002             ABOUT A BOY
# 3               1996.0                1997          ABSOLUTE POWER
# 4               1985.0                1988  THE ACCIDENTAL TOURIST
#
#                film_title      closest_book_match  goodreads_book_id  \
# 0        MURDER, SHE SAID    4.50 FROM PADDINGTON             140278
# 1   CRIME IS OUR BUSINESS    4.50 FROM PADDINGTON             140278
# 2             ABOUT A BOY             ABOUT A BOY               4271
# 3          ABSOLUTE POWER          ABSOLUTE POWER              15159
# 4  THE ACCIDENTAL TOURIST  THE ACCIDENTAL TOURIST              60792
#
#                         authors  original_publication_year  \
# 0               AGATHA CHRISTIE                     1957.0
# 1               AGATHA CHRISTIE                     1957.0
# 2                   NICK HORNBY                     1998.0
# 3                DAVID BALDACCI                     1995.0
# 4  ANNE TYLER, JENNIFER BASSETT                     1985.0
#
#            original_title                                   title  \
# 0    4.50 FROM PADDINGTON  4:50 FROM PADDINGTON (MISS MARPLE, #8)
# 1    4.50 FROM PADDINGTON  4:50 FROM PADDINGTON (MISS MARPLE, #8)
# 2             ABOUT A BOY                             ABOUT A BOY
# 3          ABSOLUTE POWER                          ABSOLUTE POWER
# 4  THE ACCIDENTAL TOURIST                  THE ACCIDENTAL TOURIST
#
#    average_rating                                    small_image_url  \
# 0            3.92  https://s.gr-assets.com/assets/nophoto/book/50...
# 1            3.92  https://s.gr-assets.com/assets/nophoto/book/50...
# 2            3.79  https://images.gr-assets.com/books/1382004144s...
# 3            4.15  https://images.gr-assets.com/books/1328399707s...
# 4            3.90  https://images.gr-assets.com/books/1502220282s...
#
#    average_rating_normalised
# 0                       78.4
# 1                       78.4
# 2                       75.8
# 3                       83.0
# 4                       78.0

# %% [markdown]
# # Films
#
# Let's try joining:
#
# - only on title
# - title AND publication date
# - title AND author (and date?)
# - title (fuzzy match)

# %%
film_ratings = pd.read_parquet("./data/film_ratings.parquet")
print(film_ratings.shape)
film_ratings.head()
# Out:
# (9366, 2)
#                                film_title  avg_film_rating
# 0                                 #HORROR        53.400000
# 1  #UNFIT: THE PSYCHOLOGY OF DONALD TRUMP        77.750000
# 2                             $ (DOLLARS)        71.333333
# 3                                   $9.99        69.012821
# 4                                     '71        78.122549

# %%
print(len(films_to_books))

merged_film_ratings = films_to_books.merge(film_ratings, on="film_title", how="inner")

print(
    f"{len(merged_film_ratings)} films merged on title alone ({100 * (len(merged_film_ratings) / len(films_to_books)):.1f}%)"
)
# Out:
# 7320
# 720 films merged on title alone (9.8%)

# %% [markdown]
# Fuzzy title matching for films

# %%
all_film_titles = film_ratings["film_title"].dropna().tolist()

films_to_books["closest_film_match"] = films_to_books["film_title"].apply(
    lambda x: most_similar_title(x, all_film_titles, max_distance=3)
)

films_to_books.head()
# Out:
#                                      Fiction work(s)  \
# 0                The 25th Hour (2001), David Benioff
# 1  3 Assassins (グラスホッパー, Gurasuhoppā) (2004), Kōt...
# 2       4.50 from Paddington (1957), Agatha Christie
# 3       4.50 from Paddington (1957), Agatha Christie
# 4                    58 Minutes (1987), Walter Wager
#
#                                   Film adaptation(s)           author  \
# 0                                   25th Hour (2002)    DAVID BENIOFF
# 1                                 Grasshopper (2015)     KŌTARŌ ISAKA
# 2                            Murder, She Said (1961)  AGATHA CHRISTIE
# 3  Crime Is Our Business (French: Le Crime est no...  AGATHA CHRISTIE
# 4                                  Die Hard 2 (1990)     WALTER WAGER
#
#    book_published_date film_published_date            book_title  \
# 0               2001.0                2002         THE 25TH HOUR
# 1               2004.0                2015           3 ASSASSINS
# 2               1957.0                1961  4.50 FROM PADDINGTON
# 3               1957.0                2008  4.50 FROM PADDINGTON
# 4               1987.0                1990            58 MINUTES
#
#               film_title    closest_book_match closest_film_match
# 0              25TH HOUR                   NaN                NaN
# 1            GRASSHOPPER                   NaN                NaN
# 2       MURDER, SHE SAID  4.50 FROM PADDINGTON                NaN
# 3  CRIME IS OUR BUSINESS  4.50 FROM PADDINGTON                NaN
# 4             DIE HARD 2                   NaN                NaN

# %%
films_to_books[films_to_books["closest_film_match"].notna()]
# Out:
#                                         Fiction work(s)  \
# 5     69 (シクスティナイン, Shikusutinain) (1987), Ryu Murakami
# 13    Adam Resurrected (Hebrew: אדם בן כלב) (1969), ...
# 14                      Adams Fall (2000), Sean Desmond
# 15                   Addie Pray (1971), Joe David Brown
# 17                    Adolphe (1816), Benjamin Constant
# ...                                                 ...
# 7277                         Contact (1985), Carl Sagan
# 7299  The Count of Monte Cristo (French: Le comte de...
# 7306                Cracking India (1991), Bapsi Sidhwa
# 7307                        Crash (1973), J. G. Ballard
# 7308                       Creator (1980), Jeremy Leven
#
#            Film adaptation(s)             author  book_published_date  \
# 5                   69 (2004)       RYU MURAKAMI               1987.0
# 13    Adam Resurrected (2009)       YORAM KANIUK               1969.0
# 14             Abandon (2002)       SEAN DESMOND               2000.0
# 15          Paper Moon (1973)    JOE DAVID BROWN               1971.0
# 17             Adolphe (2002)  BENJAMIN CONSTANT               1816.0
# ...                       ...                ...                  ...
# 7277           Contact (1997)         CARL SAGAN               1985.0
# 7299              Veta (1986)               PÈRE                  NaN
# 7306             Earth (1998)       BAPSI SIDHWA               1991.0
# 7307             Crash (1996)      J. G. BALLARD               1973.0
# 7308           Creator (1985)       JEREMY LEVEN               1980.0
#
#      film_published_date                 book_title        film_title  \
# 5                   2004                         69                69
# 13                  2009           ADAM RESURRECTED  ADAM RESURRECTED
# 14                  2002                 ADAMS FALL           ABANDON
# 15                  1973                 ADDIE PRAY        PAPER MOON
# 17                  2002                    ADOLPHE           ADOLPHE
# ...                  ...                        ...               ...
# 7277                1997                    CONTACT           CONTACT
# 7299                1986  THE COUNT OF MONTE CRISTO              VETA
# 7306                1998             CRACKING INDIA             EARTH
# 7307                1996                      CRASH             CRASH
# 7308                1985                    CREATOR           CREATOR
#
#      closest_book_match closest_film_match
# 5                    IT                  1
# 13                  NaN   ADAM RESURRECTED
# 14                  NaN            ALADDIN
# 15                  NaN          PAPER MAN
# 17                  NaN              ADORE
# ...                 ...                ...
# 7277            CONTACT         CONTRACTED
# 7299                NaN              GRETA
# 7306                NaN              EARTH
# 7307              CRASH              TRASH
# 7308           PREDATOR           CREATION
#
# [1900 rows x 9 columns]

# %% [markdown]
# Let's abandon fuzzy matching here too and join only on title

# %%
print(len(merged_book_ratings))

merged_film_ratings = merged_book_ratings.merge(
    film_ratings, on="film_title", how="inner"
)

print(merged_film_ratings.shape)

merged_film_ratings.head()
# Out:
# 2270
# (300, 17)
#                                      Fiction work(s)      Film adaptation(s)  \
# 0  The Adventures of Sherlock Holmes (serialised ...  Sherlock Holmes (1916)
# 1  The Adventures of Sherlock Holmes (serialised ...  Sherlock Holmes (1922)
# 2    The Adventures of Tom Sawyer (1876), Mark Twain  Band of Robbers (2015)
# 3                            After (2017), Anna Todd            After (2019)
# 4                            After (2017), Anna Todd            After (2019)
#
#                author  book_published_date film_published_date  \
# 0  ARTHUR CONAN DOYLE                  NaN                1916
# 1  ARTHUR CONAN DOYLE                  NaN                1922
# 2          MARK TWAIN               1876.0                2015
# 3           ANNA TODD               2017.0                2019
# 4           ANNA TODD               2017.0                2019
#
#                           book_title       film_title  \
# 0  THE ADVENTURES OF SHERLOCK HOLMES  SHERLOCK HOLMES
# 1  THE ADVENTURES OF SHERLOCK HOLMES  SHERLOCK HOLMES
# 2       THE ADVENTURES OF TOM SAWYER  BAND OF ROBBERS
# 3                              AFTER            AFTER
# 4                              AFTER            AFTER
#
#                   closest_book_match  goodreads_book_id  \
# 0  THE ADVENTURES OF SHERLOCK HOLMES               3590
# 1  THE ADVENTURES OF SHERLOCK HOLMES               3590
# 2       THE ADVENTURES OF TOM SAWYER              24583
# 3                              AFTER           22557520
# 4                              AFTER            6338619
#
#                                  authors  original_publication_year  \
# 0                     ARTHUR CONAN DOYLE                     1892.0
# 1                     ARTHUR CONAN DOYLE                     1892.0
# 2  MARK TWAIN, GUY CARDWELL, JOHN SEELYE                     1876.0
# 3                              ANNA TODD                     2014.0
# 4                               AMY EFAW                     2009.0
#
#                       original_title                              title  \
# 0  THE ADVENTURES OF SHERLOCK HOLMES  THE ADVENTURES OF SHERLOCK HOLMES
# 1  THE ADVENTURES OF SHERLOCK HOLMES  THE ADVENTURES OF SHERLOCK HOLMES
# 2       THE ADVENTURES OF TOM SAWYER       THE ADVENTURES OF TOM SAWYER
# 3                              AFTER                  AFTER (AFTER, #1)
# 4                              AFTER                              AFTER
#
#    average_rating                                    small_image_url  \
# 0            4.29  https://s.gr-assets.com/assets/nophoto/book/50...
# 1            4.29  https://s.gr-assets.com/assets/nophoto/book/50...
# 2            3.89  https://images.gr-assets.com/books/1404811979s...
# 3            3.74  https://images.gr-assets.com/books/1438077259s...
# 4            3.73  https://s.gr-assets.com/assets/nophoto/book/50...
#
#    average_rating_normalised  avg_film_rating
# 0                       85.8        64.760000
# 1                       85.8        64.760000
# 2                       77.8        68.250000
# 3                       74.8        39.652174
# 4                       74.6        39.652174

# %%
final_data = (
    merged_film_ratings[
        [
            "book_title",
            "author",
            "book_published_date",
            "average_rating_normalised",
            "film_title",
            "film_published_date",
            "avg_film_rating",
        ]
    ]
    .drop_duplicates()
    .rename(columns={"average_rating_normalised": "avg_book_rating"})
)

print(final_data.shape)
final_data.sort_values("book_title")
# Out:
# (30, 7)
#                            book_title                       author  \
# 29                 A CLOCKWORK ORANGE              ANTHONY BURGESS
# 3                               AFTER                    ANNA TODD
# 4                               AFTER                    ANNA TODD
# 5                     ANGELS & DEMONS                    DAN BROWN
# 6                        ANNIHILATION              JEFF VANDERMEER
# 7                 BEAUTIFUL CREATURES  KAMI GARCIA, MARGARET STOHL
# 8                             BEL-AMI            GUY DE MAUPASSANT
# 9                             BEL-AMI            GUY DE MAUPASSANT
# 10                            BEL-AMI            GUY DE MAUPASSANT
# 11                            BELOVED                TONI MORRISON
# 13      BEN-HUR: A TALE OF THE CHRIST                  LEW WALLACE
# 12      BEN-HUR: A TALE OF THE CHRIST                  LEW WALLACE
# 14      BEN-HUR: A TALE OF THE CHRIST                  LEW WALLACE
# 17                      BRIGHTON ROCK                GRAHAM GREENE
# 18                      BRIGHTON ROCK                GRAHAM GREENE
# 19               CALL ME BY YOUR NAME                 ANDRÉ ACIMAN
# 21                             CARRIE                 STEPHEN KING
# 22                             CARRIE                 STEPHEN KING
# 20                             CARRIE                 STEPHEN KING
# 23                               CELL                 STEPHEN KING
# 25                          CHRISTINE                 STEPHEN KING
# 1   THE ADVENTURES OF SHERLOCK HOLMES           ARTHUR CONAN DOYLE
# 0   THE ADVENTURES OF SHERLOCK HOLMES           ARTHUR CONAN DOYLE
# 2        THE ADVENTURES OF TOM SAWYER                   MARK TWAIN
# 16                            THE BFG                   ROALD DAHL
# 15                            THE BFG                   ROALD DAHL
# 24                        THE CHAMBER                 JOHN GRISHAM
# 26           THE CHRONICLES OF NARNIA                   C.S. LEWIS
# 27           THE CHRONICLES OF NARNIA                   C.S. LEWIS
# 28                  THE CITY OF EMBER                JEANNE DUPRAU
#
#     book_published_date  avg_book_rating  \
# 29               1962.0             79.6
# 3                2017.0             74.8
# 4                2017.0             74.6
# 5                2000.0             77.0
# 6                2014.0             72.4
# 7                2009.0             75.2
# 8                1885.0             76.2
# 9                1885.0             76.2
# 10               1885.0             76.2
# 11               1987.0             75.4
# 13               1880.0             80.4
# 12               1880.0             80.4
# 14               1880.0             80.4
# 17               1938.0             74.4
# 18               1938.0             74.4
# 19               2007.0             82.6
# 21               1974.0             78.6
# 22               1974.0             78.6
# 20               1974.0             78.6
# 23               2006.0             72.8
# 25               1983.0             74.4
# 1                   NaN             85.8
# 0                   NaN             85.8
# 2                1876.0             77.8
# 16               1982.0             84.4
# 15               1982.0             84.4
# 24               1994.0             75.2
# 26                  NaN             84.8
# 27                  NaN             84.8
# 28               2003.0             77.0
#
#                                            film_title film_published_date  \
# 29                                              VINYL                1965
# 3                                               AFTER                2019
# 4                                               AFTER                2019
# 5                                     ANGELS & DEMONS                2009
# 6                                        ANNIHILATION                2018
# 7                                 BEAUTIFUL CREATURES                2013
# 8                                             BEL AMI                1939
# 9                                             BEL AMI                2005
# 10                                            BEL AMI                2012
# 11                                            BELOVED                1998
# 13                                            BEN-HUR                1959
# 12                                            BEN-HUR                1925
# 14                                            BEN-HUR                2016
# 17                                      BRIGHTON ROCK                1948
# 18                                      BRIGHTON ROCK                2010
# 19                               CALL ME BY YOUR NAME                2017
# 21                                             CARRIE                2002
# 22                                             CARRIE                2013
# 20                                             CARRIE                1976
# 23                                               CELL                2016
# 25                                          CHRISTINE                1983
# 1                                     SHERLOCK HOLMES                1922
# 0                                     SHERLOCK HOLMES                1916
# 2                                     BAND OF ROBBERS                2015
# 16                                            THE BFG                2016
# 15                                            THE BFG                1989
# 24                                        THE CHAMBER                1996
# 26           THE CHRONICLES OF NARNIA: PRINCE CASPIAN                2008
# 27  THE CHRONICLES OF NARNIA: THE VOYAGE OF THE DA...                2010
# 28                                      CITY OF EMBER                2008
#
#     avg_film_rating
# 29        48.333333
# 3         39.652174
# 4         39.652174
# 5         54.865782
# 6         78.531963
# 7         57.332192
# 8         49.108696
# 9         49.108696
# 10        49.108696
# 11        61.102941
# 13        48.799324
# 12        48.799324
# 14        48.799324
# 17        59.086957
# 18        59.086957
# 19        87.500000
# 21        58.260000
# 22        58.260000
# 20        58.260000
# 23        42.500000
# 25        74.535294
# 1         64.760000
# 0         64.760000
# 2         68.250000
# 16        69.889048
# 15        69.889048
# 24        49.000000
# 26        66.274457
# 27        56.930000
# 28        60.365696

# %% [markdown]
# Quick check - any films better?

# %%
final_data[final_data["avg_film_rating"] > final_data["avg_book_rating"]]
# Out:
#               book_title           author  book_published_date  \
# 6           ANNIHILATION  JEFF VANDERMEER               2014.0
# 19  CALL ME BY YOUR NAME     ANDRÉ ACIMAN               2007.0
# 25             CHRISTINE     STEPHEN KING               1983.0
#
#     avg_book_rating            film_title film_published_date  avg_film_rating
# 6              72.4          ANNIHILATION                2018        78.531963
# 19             82.6  CALL ME BY YOUR NAME                2017        87.500000
# 25             74.4             CHRISTINE                1983        74.535294

# %% [markdown]
# Some results but clearly lacking in film review data. Need to find another source of film review data that includes release date so we can join on both and try again.
